# %%
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[63], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
check = pd.read_csv('/app/data/gold/emory_gold.csv')

# %%
check
# Out:
#                   hospital_name billing_code  \
# 0     Emory University Hospital          001
# 1     Emory University Hospital          001
# 2     Emory University Hospital          001
# 3     Emory University Hospital          001
# 4     Emory University Hospital          001
# ...                         ...          ...
# 4789  Emory University Hospital         N905
# 4790  Emory University Hospital         N905
# 4791  Emory University Hospital         N905
# 4792  Emory University Hospital         N905
# 4793  Emory University Hospital         N905
#
#                                          procedure_type  level  \
# 0     Heart Transplant Or Implant Of Heart Assist Sy...      1
# 1     Heart Transplant Or Implant Of Heart Assist Sy...      1
# 2     Heart Transplant Or Implant Of Heart Assist Sy...      1
# 3     Heart Transplant Or Implant Of Heart Assist Sy...      1
# 4     Heart Transplant Or Implant Of Heart Assist Sy...      1
# ...                                                 ...    ...
# 4789                             Not Recognized by OPPS      1
# 4790                             Not Recognized by OPPS      1
# 4791                             Not Recognized by OPPS      1
# 4792                             Not Recognized by OPPS      1
# 4793                             Not Recognized by OPPS      1
#
#                         payer                            plan  min_rate  \
# 0                       Aetna                        Exchange  36969.83
# 1                        BCBS                             HMO  36969.83
# 2                        BCBS  Pathways Other Commercial Plan  36969.83
# 3                      Clover      Medicare Managed Care Plan  36969.83
# 4                      Humana      Medicare Managed Care Plan  36969.83
# ...                       ...                             ...       ...
# 4789              Peach State      Medicaid Managed Care Plan     33.37
# 4790  Peach State Health Plan                        Exchange     33.37
# 4791         UnitedHealthCare                             HMO     33.37
# 4792         UnitedHealthCare      Medicare Managed Care Plan     33.37
# 4793         UnitedHealthCare                             PPO     33.37
#
#         max_rate  median_rate  record_count
# 0     1602134.51   1602134.51             1
# 1     1602134.51    168439.38             1
# 2     1602134.51    270649.38             1
# 3     1602134.51    236430.08             1
# 4     1602134.51    310809.98             1
# ...          ...          ...           ...
# 4789      223.94        42.24             1
# 4790      223.94        33.37             1
# 4791      223.94       220.26             1
# 4792      223.94       113.26             1
# 4793      223.94       223.94             1
#
# [4794 rows x 10 columns]

# %%
check.describe(include='all')
inpatient = check[check['billing_code_type'] == 'MS-DRG']
outpatient = check[check['billing_code_type'] == 'APC']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'billing_code_type'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[75], line 2
#       1 check.describe(include='all')
# ----> 2 inpatient = check[check['billing_code_type'] == 'MS-DRG']
#       3 outpatient = check[check['billing_code_type'] == 'APC']
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File /usr/local/lib/python3.10/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'billing_code_type'

# %%
inpatient.describe(include='all')
# Out:
#                     hospital_name                                address  \
# count                        2690                                   2690
# unique                          1                                      1
# top     Emory University Hospital  1364 Clifton Rd NE, Atlanta, GA 30322
# freq                         2690                                   2690
# mean                          NaN                                    NaN
# std                           NaN                                    NaN
# min                           NaN                                    NaN
# 25%                           NaN                                    NaN
# 50%                           NaN                                    NaN
# 75%                           NaN                                    NaN
# max                           NaN                                    NaN
#
#        effective_date billing_code_type billing_code  \
# count            2690              2690         2690
# unique              1                 1          533
# top        2025-10-01            MS-DRG          291
# freq             2690              2690           19
# mean              NaN               NaN          NaN
# std               NaN               NaN          NaN
# min               NaN               NaN          NaN
# 25%               NaN               NaN          NaN
# 50%               NaN               NaN          NaN
# 75%               NaN               NaN          NaN
# max               NaN               NaN          NaN
#
#                              description billing_class    setting payer  \
# count                               2690          2690       2690  2690
# unique                               528             1          1    17
# top     Heart Failure And Shock With Mcc      facility  inpatient  BCBS
# freq                                  19          2690       2690   632
# mean                                 NaN           NaN        NaN   NaN
# std                                  NaN           NaN        NaN   NaN
# min                                  NaN           NaN        NaN   NaN
# 25%                                  NaN           NaN        NaN   NaN
# 50%                                  NaN           NaN        NaN   NaN
# 75%                                  NaN           NaN        NaN   NaN
# max                                  NaN           NaN        NaN   NaN
#
#                               plan  min_negotiated_rate  max_negotiated_rate  \
# count                         2690          2690.000000         2.690000e+03
# unique                          13                  NaN                  NaN
# top     Medicare Managed Care Plan                  NaN                  NaN
# freq                           941                  NaN                  NaN
# mean                           NaN         11813.005613         8.357058e+04
# std                            NaN         16271.473663         1.417881e+05
# min                            NaN          1002.460000         1.180030e+03
# 25%                            NaN          2685.700000         2.161390e+04
# 50%                            NaN          7656.630000         4.046356e+04
# 75%                            NaN         15291.452500         8.719090e+04
# max                            NaN        318837.590000         1.602135e+06
#
#         estimated_amount   level                    procedure_type
# count       2.690000e+03  2690.0                              2690
# unique               NaN     NaN                               528
# top                  NaN     NaN  Heart Failure And Shock With Mcc
# freq                 NaN     NaN                                19
# mean        3.572440e+04     1.0                               NaN
# std         6.959432e+04     0.0                               NaN
# min         1.002460e+03     1.0                               NaN
# 25%         1.062877e+04     1.0                               NaN
# 50%         1.823319e+04     1.0                               NaN
# 75%         3.487244e+04     1.0                               NaN
# max         1.602135e+06     1.0                               NaN

# %%
outpatient['payer'].unique()
# Out:
# array(['Aetna', 'BCBS', 'Cigna', 'Kaiser', 'Oscar Health',
#        'Peach State Health Plan', 'Humana', 'UnitedHealthCare',
#        'Amerigroup', 'CareSource', 'Peach State', 'Clover', 'Wellcare',
#        'Optum', 'Sonder Health Plans', 'PHCS', 'Contigo COE',
#        'Beechstreet', 'Multiplan'], dtype=object)

# %%
outpatient.describe(include='all')
# Out:
#                     hospital_name                                address  \
# count                        2104                                   2104
# unique                          1                                      1
# top     Emory University Hospital  1364 Clifton Rd NE, Atlanta, GA 30322
# freq                         2104                                   2104
# mean                          NaN                                    NaN
# std                           NaN                                    NaN
# min                           NaN                                    NaN
# 25%                           NaN                                    NaN
# 50%                           NaN                                    NaN
# 75%                           NaN                                    NaN
# max                           NaN                                    NaN
#
#        effective_date billing_code_type billing_code  \
# count            2104              2104         2104
# unique              1                 1          155
# top        2025-10-01               APC         5572
# freq             2104              2104           31
# mean              NaN               NaN          NaN
# std               NaN               NaN          NaN
# min               NaN               NaN          NaN
# 25%               NaN               NaN          NaN
# 50%               NaN               NaN          NaN
# 75%               NaN               NaN          NaN
# max               NaN               NaN          NaN
#
#                           description billing_class     setting payer  \
# count                            2104          2104        2104  2104
# unique                            155             1           1    19
# top     Level 2 Imaging with Contrast      facility  outpatient  BCBS
# freq                               31          2104        2104   427
# mean                              NaN           NaN         NaN   NaN
# std                               NaN           NaN         NaN   NaN
# min                               NaN           NaN         NaN   NaN
# 25%                               NaN           NaN         NaN   NaN
# 50%                               NaN           NaN         NaN   NaN
# 75%                               NaN           NaN         NaN   NaN
# max                               NaN           NaN         NaN   NaN
#
#                               plan  min_negotiated_rate  max_negotiated_rate  \
# count                         2104          2104.000000          2104.000000
# unique                          15                  NaN                  NaN
# top     Medicare Managed Care Plan                  NaN                  NaN
# freq                           496                  NaN                  NaN
# mean                           NaN          1015.449225         12341.454173
# std                            NaN          1915.352243         14503.449250
# min                            NaN             1.270000            16.820000
# 25%                            NaN            45.120000          1949.620000
# 50%                            NaN           228.820000          6611.320000
# 75%                            NaN          1310.520000         16608.120000
# max                            NaN         21477.800000         93735.370000
#
#         estimated_amount        level            procedure_type
# count        2104.000000  2104.000000                      2104
# unique               NaN          NaN                        59
# top                  NaN          NaN  Imaging without Contrast
# freq                 NaN          NaN                       113
# mean         4567.753531     2.959601                       NaN
# std          7290.358123     3.029540                       NaN
# min             1.270000     1.000000                       NaN
# 25%           380.067500     1.000000                       NaN
# 50%          1859.805000     2.000000                       NaN
# 75%          5513.590000     4.000000                       NaN
# max         93735.370000    22.000000                       NaN

# %%
inpatient['plan'].unique()
# Out:
# array(['Exchange', 'HMO', 'Pathways Other Commercial Plan',
#        'Medicare Managed Care Plan', 'PPO', 'Medicaid Managed Care Plan',
#        'Blue Value Secure Medicare Managed Care Plan',
#        'HealthSpring Medicare Managed Care Plan', 'HMO/POS',
#        'All Commercial Plans', 'Other Commercial Plan',
#        'HPN Other Commercial Plan', 'Behavioral Health Plan'],
#       dtype=object)
