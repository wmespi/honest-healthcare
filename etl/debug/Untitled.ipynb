# %%
import pandas as pd

# %%
check = pd.read_csv('/app/data/gold/emory_gold.csv')

# %%
check.hospital_name.unique()
# Out:
# array(['Emory Decatur Hospital', 'Emory Hillandale Hospital',
#        'Emory Johns Creek Hospital',
#        'Emory Long Term Acute Care Hospital',
#        'Emory Rehabilitation Hospital', 'Emory Saint Joseph S Hospital',
#        'Emory University Hospital', 'Emory University Hospital Midtown'],
#       dtype=object)

# %%
check.describe(include='all')
# Out:
#                     hospital_name billing_code billing_code_type  \
# count                       21394        21394             21394
# unique                          8          910                 2
# top     Emory University Hospital         5025            MS-DRG
# freq                         4794          178             10976
# mean                          NaN          NaN               NaN
# std                           NaN          NaN               NaN
# min                           NaN          NaN               NaN
# 25%                           NaN          NaN               NaN
# 50%                           NaN          NaN               NaN
# 75%                           NaN          NaN               NaN
# max                           NaN          NaN               NaN
#
#                   procedure_type    setting  payer  \
# count                      21394      21394  21394
# unique                       908          2     26
# top     Type A ED Visits Level 5  inpatient   BCBS
# freq                         178      10976   4098
# mean                         NaN        NaN    NaN
# std                          NaN        NaN    NaN
# min                          NaN        NaN    NaN
# 25%                          NaN        NaN    NaN
# 50%                          NaN        NaN    NaN
# 75%                          NaN        NaN    NaN
# max                          NaN        NaN    NaN
#
#                               plan       min_rate      max_rate   median_rate  \
# count                        21394   21394.000000  2.139400e+04  2.139400e+04
# unique                          22            NaN           NaN           NaN
# top     Medicare Managed Care Plan            NaN           NaN           NaN
# freq                          6643            NaN           NaN           NaN
# mean                           NaN    6167.868925  3.370738e+04  1.541363e+04
# std                            NaN   11679.340956  7.871765e+04  3.826616e+04
# min                            NaN       1.000000  1.682000e+01  1.000000e+00
# 25%                            NaN     177.350000  5.424480e+03  1.494525e+03
# 50%                            NaN    2366.940000  1.690603e+04  7.151995e+03
# 75%                            NaN    7607.327500  3.468644e+04  1.693735e+04
# max                            NaN  325531.630000  2.581887e+06  2.581887e+06
#
#         record_count
# count        21394.0
# unique           NaN
# top              NaN
# freq             NaN
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %%
check[check.hospital_name == 'Emory University Hospital'].describe(include='all')
# Out:
#                     hospital_name billing_code billing_code_type  \
# count                        4794         4794              4794
# unique                          1          688                 2
# top     Emory University Hospital         5572            MS-DRG
# freq                         4794           31              2690
# mean                          NaN          NaN               NaN
# std                           NaN          NaN               NaN
# min                           NaN          NaN               NaN
# 25%                           NaN          NaN               NaN
# 50%                           NaN          NaN               NaN
# 75%                           NaN          NaN               NaN
# max                           NaN          NaN               NaN
#
#                        procedure_type    setting payer  \
# count                            4794       4794  4794
# unique                            683          2    19
# top     Imaging with Contrast Level 2  inpatient  BCBS
# freq                               31       2690  1059
# mean                              NaN        NaN   NaN
# std                               NaN        NaN   NaN
# min                               NaN        NaN   NaN
# 25%                               NaN        NaN   NaN
# 50%                               NaN        NaN   NaN
# 75%                               NaN        NaN   NaN
# max                               NaN        NaN   NaN
#
#                               plan       min_rate      max_rate   median_rate  \
# count                         4794    4794.000000  4.794000e+03  4.794000e+03
# unique                          15            NaN           NaN           NaN
# top     Medicare Managed Care Plan            NaN           NaN           NaN
# freq                          1437            NaN           NaN           NaN
# mean                           NaN    7074.153164  5.230940e+04  2.205031e+04
# std                            NaN   13374.034202  1.123424e+05  5.458650e+04
# min                            NaN       1.270000  1.682000e+01  1.270000e+00
# 25%                            NaN     287.110000  7.911900e+03  2.239863e+03
# 50%                            NaN    2385.670000  2.267525e+04  9.603610e+03
# 75%                            NaN    8956.900000  5.094242e+04  2.222559e+04
# max                            NaN  318837.590000  1.602135e+06  1.602135e+06
#
#         record_count
# count         4794.0
# unique           NaN
# top              NaN
# freq             NaN
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %%
check.describe(include='all')
inpatient = check[check['setting'] == 'inpatient']
outpatient = check[check['setting'] == 'outpatient']

# %%
inpatient.describe(include='all')
# Out:
#                     hospital_name billing_code billing_code_type  \
# count                       10976        10976             10976
# unique                          8          702                 1
# top     Emory University Hospital          871            MS-DRG
# freq                         2690          108             10976
# mean                          NaN          NaN               NaN
# std                           NaN          NaN               NaN
# min                           NaN          NaN               NaN
# 25%                           NaN          NaN               NaN
# 50%                           NaN          NaN               NaN
# 75%                           NaN          NaN               NaN
# max                           NaN          NaN               NaN
#
#                                            procedure_type    setting  payer  \
# count                                               10976      10976  10976
# unique                                                700          1     23
# top     Septicemia Or Severe Sepsis Without Mv >96 Hou...  inpatient   BCBS
# freq                                                  108      10976   2139
# mean                                                  NaN        NaN    NaN
# std                                                   NaN        NaN    NaN
# min                                                   NaN        NaN    NaN
# 25%                                                   NaN        NaN    NaN
# 50%                                                   NaN        NaN    NaN
# 75%                                                   NaN        NaN    NaN
# max                                                   NaN        NaN    NaN
#
#                               plan       min_rate      max_rate   median_rate  \
# count                        10976   10976.000000  1.097600e+04  1.097600e+04
# unique                          19            NaN           NaN           NaN
# top     Medicare Managed Care Plan            NaN           NaN           NaN
# freq                          4012            NaN           NaN           NaN
# mean                           NaN   11105.454697  5.547992e+04  2.619585e+04
# std                            NaN   14478.697698  1.045406e+05  5.066618e+04
# min                            NaN    1000.000000  1.175640e+03  1.000000e+03
# 25%                            NaN    3672.000000  1.782214e+04  8.889575e+03
# 50%                            NaN    7070.440000  2.931322e+04  1.497822e+04
# 75%                            NaN   13531.530000  5.628586e+04  2.780538e+04
# max                            NaN  325531.630000  2.581887e+06  2.581887e+06
#
#         record_count
# count        10976.0
# unique           NaN
# top              NaN
# freq             NaN
# mean             1.0
# std              0.0
# min              1.0
# 25%              1.0
# 50%              1.0
# 75%              1.0
# max              1.0

# %%
inpatient[inpatient.median_rate > 2000000]
# Out:
#             hospital_name billing_code billing_code_type  \
# 1  Emory Decatur Hospital          004            MS-DRG
#
#                                       procedure_type    setting payer plan  \
# 1  Tracheostomy With Mv >96 Hours Or Principal Di...  inpatient  BCBS  PPO
#
#     min_rate    max_rate  median_rate  record_count
# 1  107756.42  2581887.23   2581887.23             1

# %%
outpatient[outpatient.procedure_type == 'Airway Endoscopy Level 3'][['hospital_name', 'payer', 'plan']].drop_duplicates().sort_values(['hospital_name', 'payer', 'plan'])
# 10352                                      Exchange
# 10353                                           HMO
# 14380                                      Exchange
# 14381  Blue Value Secure Medicare Managed Care Plan
# 14382                                           HMO
# 14383                                           PPO
# 14384                Pathways Other Commercial Plan
# 14385                                       HMO/POS
# 14386                    Medicare Managed Care Plan
# 14387                                           HMO
# 14388                    Medicare Managed Care Plan
# 18812                                      Exchange
# 18813                                       HMO/POS
# 18814                    Medicare Managed Care Plan
# 18815                    Medicaid Managed Care Plan
# 18816  Blue Value Secure Medicare Managed Care Plan
# 18817                                           HMO
# 18818                                           PPO
# 18819                Pathways Other Commercial Plan
# 18820                                       HMO/POS
# 18821                    Medicare Managed Care Plan
# 18822                                           HMO
# 18823                    Medicare Managed Care Plan
# 18824                          All Commercial Plans
# 18825                    Medicaid Managed Care Plan
# 18826                                      Exchange
# 18827                                           HMO
# 18828                    Medicare Managed Care Plan
# 18829                                           PPO

# %%
outpatient[outpatient.procedure_type == 'CT and CTA without Contrast Composite'].hospital_name.unique()
# Out:
# array(['Emory Decatur Hospital'], dtype=object)

# %%
outpatient.describe(include='all')
# Out:
#                  hospital_name billing_code billing_code_type  \
# count                    10418        10418             10418
# unique                       7          208                 1
# top     Emory Decatur Hospital         5025               APC
# freq                      2456          178             10418
# mean                       NaN          NaN               NaN
# std                        NaN          NaN               NaN
# min                        NaN          NaN               NaN
# 25%                        NaN          NaN               NaN
# 50%                        NaN          NaN               NaN
# 75%                        NaN          NaN               NaN
# max                        NaN          NaN               NaN
#
#                   procedure_type     setting  payer  \
# count                      10418       10418  10418
# unique                       208           1     26
# top     Type A ED Visits Level 5  outpatient   BCBS
# freq                         178       10418   1959
# mean                         NaN         NaN    NaN
# std                          NaN         NaN    NaN
# min                          NaN         NaN    NaN
# 25%                          NaN         NaN    NaN
# 50%                          NaN         NaN    NaN
# 75%                          NaN         NaN    NaN
# max                          NaN         NaN    NaN
#
#                               plan       min_rate       max_rate  \
# count                        10418   10418.000000   10418.000000
# unique                          21            NaN            NaN
# top     Medicare Managed Care Plan            NaN            NaN
# freq                          2631            NaN            NaN
# mean                           NaN     965.820411   10768.671161
# std                            NaN    2553.440252   13622.939147
# min                            NaN       1.000000      16.820000
# 25%                            NaN      44.150000    1708.000000
# 50%                            NaN     170.810000    5424.480000
# 75%                            NaN     796.060000   13254.230000
# max                            NaN  100707.050000  108073.240000
#
#           median_rate  record_count
# count    10418.000000       10418.0
# unique            NaN           NaN
# top               NaN           NaN
# freq              NaN           NaN
# mean      4053.900749           1.0
# std       7145.230294           0.0
# min          1.000000           1.0
# 25%        355.230000           1.0
# 50%       1460.710000           1.0
# 75%       4657.200000           1.0
# max     108073.240000           1.0

# %%
inpatient['plan'].unique()
# Out:
# array(['Exchange', 'HMO', 'Pathways Other Commercial Plan',
#        'Medicare Managed Care Plan', 'PPO', 'Medicaid Managed Care Plan',
#        'Blue Value Secure Medicare Managed Care Plan',
#        'HealthSpring Medicare Managed Care Plan', 'HMO/POS',
#        'All Commercial Plans', 'Other Commercial Plan',
#        'HPN Other Commercial Plan', 'Behavioral Health Plan'],
#       dtype=object)
